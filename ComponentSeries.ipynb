# %%
import networkx as nx
import pandas
import numpy as np
import json
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
with open("data/loyaltygraphs2.json") as f:
    runs = json.load(f)

# %%
all_graph_series = []
for run in runs:
    graph_series = []
    for array in run["endMatrices"]:
        matrix = np.array(array)
        graph = nx.Graph(matrix)
        graph_series.append(graph)
    all_graph_series.append(graph_series)

# %%
component_count = [len(nx.connected_components(graph)[0]) for graph in all_graph_series[1]]
component_count = pandas.Series(component_count)
component_count.plot()

# %%
nx.draw(all_graph_series[1][0])

# %%
nx.draw(all_graph_series[1][50])
